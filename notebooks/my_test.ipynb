# %%
import sys
sys.executable
# Out:
# 'c:\\Users\\keyton.porras\\projects\\work\\utility-billing\\.venv\\Scripts\\python.exe'

# %%
import pandas as pd
import matplotlib.pyplot as plt

print("pandas:", pd.__version__)
plt.plot([1,2,3],[1,4,9])
plt.title("Sanity plot")
plt.show()
# Out:
# pandas: 2.3.2
